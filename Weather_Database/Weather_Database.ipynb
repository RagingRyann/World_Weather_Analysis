# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
# Output is zip object in memory. 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_cond = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_cond})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | churapcha
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | komsomolskiy
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | isangel
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | jalu
# Processing Record 12 of Set 1 | vostok
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | puerto pinasco
# 'coord'
# Processing Record 15 of Set 1 | fethiye
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | kununurra
# Processing Record 22 of Set 1 | flinders
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | port blair
# Processing Record 27 of Set 1 | northam
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | oruro
# Processing Record 30 of Set 1 | galway
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | borogontsy
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | coquimbo
# Processing Record 35 of Set 1 | tromso
# Processing Record 36 of Set 1 | pisco
# Processing Record 37 of Set 1 | zhezkazgan
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | kavieng
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | hami
# Processing Record 42 of Set 1 | rokiskis
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | rampur
# Processing Record 46 of Set 1 | dafeng
# Processing Record 47 of Set 1 | tiznit
# Processing Record 48 of Set 1 | hambantota
# Processing Record 49 of Set 1 | tezu
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | iralaya
# Processing Record 2 of Set 2 | agadez
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | iguape
# Processing Record 5 of Set 2 | lompoc
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | san policarpo
# Processing Record 8 of Set 2 | shenxian
# Processing Record 9 of Set 2 | lavrentiya
# Processing Record 10 of Set 2 | sindand
# 'coord'
# Processing Record 11 of Set 2 | kulu
# Processing Record 12 of Set 2 | kaitangata
# Processing Record 13 of Set 2 | sentyabrskiy
# 'coord'
# Processing Record 14 of Set 2 | klaksvik
# Processing Record 15 of Set 2 | dingle
# Processing Record 16 of Set 2 | mbandaka
# Processing Record 17 of Set 2 | tucumcari
# Processing Record 18 of Set 2 | linqiong
# Processing Record 19 of Set 2 | sawakin
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | gaomi
# Processing Record 23 of Set 2 | apatou
# Processing Record 24 of Set 2 | severnyy
# Processing Record 25 of Set 2 | mys shmidta
# 'coord'
# Processing Record 26 of Set 2 | tuatapere
# Processing Record 27 of Set 2 | vrises
# Processing Record 28 of Set 2 | freeport
# Processing Record 29 of Set 2 | novikovo
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | portland
# Processing Record 32 of Set 2 | bouguenais
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | antofagasta
# Processing Record 35 of Set 2 | tieling
# Processing Record 36 of Set 2 | sao mateus
# Processing Record 37 of Set 2 | saleaula
# 'coord'
# Processing Record 38 of Set 2 | wainwright
# Processing Record 39 of Set 2 | kamenskoye
# 'coord'
# Processing Record 40 of Set 2 | padang
# Processing Record 41 of Set 2 | kinkala
# Processing Record 42 of Set 2 | praxedis guerrero
# Processing Record 43 of Set 2 | alta floresta
# Processing Record 44 of Set 2 | jurado
# Processing Record 45 of Set 2 | glubokoe
# 'coord'
# Processing Record 46 of Set 2 | novyy urengoy
# Processing Record 47 of Set 2 | boulder city
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | attawapiskat
# 'coord'
# Processing Record 50 of Set 2 | fasa
# Processing Record 1 of Set 3 | los llanos de aridane
# Processing Record 2 of Set 3 | kastamonu
# Processing Record 3 of Set 3 | coruripe
# Processing Record 4 of Set 3 | poum
# Processing Record 5 of Set 3 | nome
# Processing Record 6 of Set 3 | tateyama
# Processing Record 7 of Set 3 | camana
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | unidos
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | laktasi
# Processing Record 12 of Set 3 | barrow
# Processing Record 13 of Set 3 | cockburn town
# Processing Record 14 of Set 3 | molo
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | bassar
# Processing Record 17 of Set 3 | tucuman
# Processing Record 18 of Set 3 | tura
# Processing Record 19 of Set 3 | acari
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | cabo san lucas
# Processing Record 22 of Set 3 | avera
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | wawa
# Processing Record 25 of Set 3 | kinarut
# Processing Record 26 of Set 3 | kourou
# Processing Record 27 of Set 3 | abha
# Processing Record 28 of Set 3 | rio grande
# Processing Record 29 of Set 3 | shimoda
# Processing Record 30 of Set 3 | barentsburg
# 'coord'
# Processing Record 31 of Set 3 | ponta do sol
# Processing Record 32 of Set 3 | port augusta
# Processing Record 33 of Set 3 | goundam
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | iqaluit
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | bay roberts
# Processing Record 38 of Set 3 | kuruman
# Processing Record 39 of Set 3 | hrymayliv
# Processing Record 40 of Set 3 | la palma
# Processing Record 41 of Set 3 | dzaoudzi
# Processing Record 42 of Set 3 | carnarvon
# Processing Record 43 of Set 3 | troitsko-pechorsk
# Processing Record 44 of Set 3 | puerto ayora
# Processing Record 45 of Set 3 | jacareacanga
# Processing Record 46 of Set 3 | upernavik
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | orlik
# Processing Record 49 of Set 3 | kahului
# Processing Record 50 of Set 3 | valdivia
# Processing Record 1 of Set 4 | igarka
# Processing Record 2 of Set 4 | vakhtan
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | arkadelphia
# Processing Record 5 of Set 4 | imbituba
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | laukaa
# Processing Record 8 of Set 4 | obihiro
# Processing Record 9 of Set 4 | berlevag
# Processing Record 10 of Set 4 | leningradskiy
# Processing Record 11 of Set 4 | vardo
# Processing Record 12 of Set 4 | hilo
# Processing Record 13 of Set 4 | port hawkesbury
# Processing Record 14 of Set 4 | kodiak
# Processing Record 15 of Set 4 | eldikan
# 'coord'
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | kelo
# Processing Record 18 of Set 4 | chuy
# Processing Record 19 of Set 4 | qaqortoq
# Processing Record 20 of Set 4 | utiroa
# 'coord'
# Processing Record 21 of Set 4 | svetlogorsk
# Processing Record 22 of Set 4 | yerbogachen
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | pachino
# Processing Record 25 of Set 4 | yar-sale
# Processing Record 26 of Set 4 | micheweni
# Processing Record 27 of Set 4 | hovd
# Processing Record 28 of Set 4 | taolanaro
# 'coord'
# Processing Record 29 of Set 4 | fortuna
# Processing Record 30 of Set 4 | sao filipe
# Processing Record 31 of Set 4 | sao jose de ribamar
# Processing Record 32 of Set 4 | tallahassee
# Processing Record 33 of Set 4 | tomatlan
# Processing Record 34 of Set 4 | saint-augustin
# Processing Record 35 of Set 4 | muravlenko
# Processing Record 36 of Set 4 | tasiilaq
# Processing Record 37 of Set 4 | uptar
# Processing Record 38 of Set 4 | guerrero negro
# Processing Record 39 of Set 4 | linxia
# Processing Record 40 of Set 4 | itupeva
# Processing Record 41 of Set 4 | udachnyy
# Processing Record 42 of Set 4 | qaanaaq
# Processing Record 43 of Set 4 | baoqing
# Processing Record 44 of Set 4 | jiancheng
# Processing Record 45 of Set 4 | te anau
# Processing Record 46 of Set 4 | hirara
# Processing Record 47 of Set 4 | tuktoyaktuk
# Processing Record 48 of Set 4 | ennis
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | illoqqortoormiut
# 'coord'
# Processing Record 1 of Set 5 | ios
# Processing Record 2 of Set 5 | port alfred
# Processing Record 3 of Set 5 | kapuskasing
# Processing Record 4 of Set 5 | formoso do araguaia
# 'coord'
# Processing Record 5 of Set 5 | saskylakh
# Processing Record 6 of Set 5 | la ronge
# Processing Record 7 of Set 5 | uwayl
# 'coord'
# Processing Record 8 of Set 5 | pudozh
# Processing Record 9 of Set 5 | hun
# Processing Record 10 of Set 5 | amderma
# 'coord'
# Processing Record 11 of Set 5 | fulnek
# Processing Record 12 of Set 5 | sorong
# Processing Record 13 of Set 5 | calvinia
# Processing Record 14 of Set 5 | nuuk
# Processing Record 15 of Set 5 | saint-francois
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | nemuro
# Processing Record 18 of Set 5 | umzimvubu
# 'coord'
# Processing Record 19 of Set 5 | carauari
# Processing Record 20 of Set 5 | nizhneyansk
# 'coord'
# Processing Record 21 of Set 5 | ismailia
# Processing Record 22 of Set 5 | weihe
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | todos santos
# Processing Record 25 of Set 5 | hithadhoo
# Processing Record 26 of Set 5 | hearst
# Processing Record 27 of Set 5 | tawkar
# 'coord'
# Processing Record 28 of Set 5 | yomitan
# 'coord'
# Processing Record 29 of Set 5 | asau
# Processing Record 30 of Set 5 | qatana
# Processing Record 31 of Set 5 | sorvag
# 'coord'
# Processing Record 32 of Set 5 | kribi
# Processing Record 33 of Set 5 | mountain home
# Processing Record 34 of Set 5 | fort nelson
# Processing Record 35 of Set 5 | sao joao da barra
# Processing Record 36 of Set 5 | atar
# Processing Record 37 of Set 5 | khonuu
# 'coord'
# Processing Record 38 of Set 5 | jumla
# Processing Record 39 of Set 5 | mandera
# Processing Record 40 of Set 5 | alice springs
# Processing Record 41 of Set 5 | doka
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | beni
# Processing Record 44 of Set 5 | vawkavysk
# Processing Record 45 of Set 5 | grand river south east
# 'coord'
# Processing Record 46 of Set 5 | akalkot
# Processing Record 47 of Set 5 | yaviza
# Processing Record 48 of Set 5 | havre-saint-pierre
# Processing Record 49 of Set 5 | le vauclin
# Processing Record 50 of Set 5 | samana
# Processing Record 1 of Set 6 | cayenne
# Processing Record 2 of Set 6 | salalah
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | diapaga
# Processing Record 5 of Set 6 | sistranda
# Processing Record 6 of Set 6 | rawson
# Processing Record 7 of Set 6 | seoul
# Processing Record 8 of Set 6 | lushunkou
# 'coord'
# Processing Record 9 of Set 6 | marcona
# 'coord'
# Processing Record 10 of Set 6 | coronado
# Processing Record 11 of Set 6 | xai-xai
# Processing Record 12 of Set 6 | warrington
# Processing Record 13 of Set 6 | darnah
# Processing Record 14 of Set 6 | baracoa
# Processing Record 15 of Set 6 | kamenka
# Processing Record 16 of Set 6 | abu dhabi
# Processing Record 17 of Set 6 | faanui
# Processing Record 18 of Set 6 | half moon bay
# Processing Record 19 of Set 6 | pevek
# Processing Record 20 of Set 6 | fukuma
# Processing Record 21 of Set 6 | caravelas
# Processing Record 22 of Set 6 | beloha
# Processing Record 23 of Set 6 | kasungu
# Processing Record 24 of Set 6 | deputatskiy
# Processing Record 25 of Set 6 | taquaritinga do norte
# Processing Record 26 of Set 6 | viedma
# Processing Record 27 of Set 6 | saint-pierre
# Processing Record 28 of Set 6 | kaarina
# Processing Record 29 of Set 6 | palm desert
# Processing Record 30 of Set 6 | neiafu
# Processing Record 31 of Set 6 | hyeres
# Processing Record 32 of Set 6 | kudahuvadhoo
# Processing Record 33 of Set 6 | sylacauga
# Processing Record 34 of Set 6 | odweyne
# Processing Record 35 of Set 6 | emerald
# Processing Record 36 of Set 6 | acapulco
# Processing Record 37 of Set 6 | gayny
# Processing Record 38 of Set 6 | kushima
# Processing Record 39 of Set 6 | broome
# Processing Record 40 of Set 6 | yichang
# Processing Record 41 of Set 6 | castro
# Processing Record 42 of Set 6 | sola
# Processing Record 43 of Set 6 | villa carlos paz
# Processing Record 44 of Set 6 | leh
# Processing Record 45 of Set 6 | waingapu
# Processing Record 46 of Set 6 | lebu
# Processing Record 47 of Set 6 | barranca
# Processing Record 48 of Set 6 | clyde river
# Processing Record 49 of Set 6 | port macquarie
# Processing Record 50 of Set 6 | narsaq
# Processing Record 1 of Set 7 | pemangkat
# Processing Record 2 of Set 7 | veisiejai
# Processing Record 3 of Set 7 | maracacume
# Processing Record 4 of Set 7 | buala
# Processing Record 5 of Set 7 | fulton
# Processing Record 6 of Set 7 | khatanga
# Processing Record 7 of Set 7 | peniche
# Processing Record 8 of Set 7 | nusaybin
# Processing Record 9 of Set 7 | gboko
# Processing Record 10 of Set 7 | husavik
# Processing Record 11 of Set 7 | ribeira grande
# Processing Record 12 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 7 | toliary
# 'coord'
# Processing Record 14 of Set 7 | vershino-shakhtaminskiy
# Processing Record 15 of Set 7 | kapoeta
# Processing Record 16 of Set 7 | wajima
# Processing Record 17 of Set 7 | chapais
# Processing Record 18 of Set 7 | mount gambier
# Processing Record 19 of Set 7 | muros
# Processing Record 20 of Set 7 | puerto colombia
# Processing Record 21 of Set 7 | arica
# Processing Record 22 of Set 7 | aktau
# Processing Record 23 of Set 7 | marietta
# Processing Record 24 of Set 7 | nieuw amsterdam
# Processing Record 25 of Set 7 | saint-philippe
# Processing Record 26 of Set 7 | salinopolis
# Processing Record 27 of Set 7 | manokwari
# Processing Record 28 of Set 7 | palmas de monte alto
# Processing Record 29 of Set 7 | concarneau
# Processing Record 30 of Set 7 | saldanha
# Processing Record 31 of Set 7 | nouadhibou
# Processing Record 32 of Set 7 | aswan
# Processing Record 33 of Set 7 | bluff
# Processing Record 34 of Set 7 | omaruru
# Processing Record 35 of Set 7 | arlit
# Processing Record 36 of Set 7 | bonthe
# Processing Record 37 of Set 7 | baykit
# Processing Record 38 of Set 7 | touros
# Processing Record 39 of Set 7 | el retorno
# Processing Record 40 of Set 7 | kohtla-jarve
# Processing Record 41 of Set 7 | tabas
# Processing Record 42 of Set 7 | armacao dos buzios
# 'coord'
# Processing Record 43 of Set 7 | alofi
# Processing Record 44 of Set 7 | labuhan
# Processing Record 45 of Set 7 | assiniboia
# Processing Record 46 of Set 7 | kyra
# Processing Record 47 of Set 7 | port hardy
# Processing Record 48 of Set 7 | homer
# Processing Record 49 of Set 7 | tunduru
# 'coord'
# Processing Record 50 of Set 7 | fare
# Processing Record 1 of Set 8 | belushya guba
# 'coord'
# Processing Record 2 of Set 8 | severo-kurilsk
# Processing Record 3 of Set 8 | port elizabeth
# Processing Record 4 of Set 8 | horsham
# Processing Record 5 of Set 8 | whyalla
# Processing Record 6 of Set 8 | cururupu
# Processing Record 7 of Set 8 | samalaeulu
# 'coord'
# Processing Record 8 of Set 8 | bereda
# Processing Record 9 of Set 8 | hamilton
# Processing Record 10 of Set 8 | ikongo
# Processing Record 11 of Set 8 | xining
# Processing Record 12 of Set 8 | chilca
# Processing Record 13 of Set 8 | puerto escondido
# Processing Record 14 of Set 8 | vestmannaeyjar
# Processing Record 15 of Set 8 | haines junction
# Processing Record 16 of Set 8 | miri
# Processing Record 17 of Set 8 | omboue
# Processing Record 18 of Set 8 | oranjestad
# Processing Record 19 of Set 8 | mapiripan
# Processing Record 20 of Set 8 | halalo
# 'coord'
# Processing Record 21 of Set 8 | teguise
# Processing Record 22 of Set 8 | kupang
# Processing Record 23 of Set 8 | kruisfontein
# Processing Record 24 of Set 8 | sao sebastiao
# Processing Record 25 of Set 8 | takoradi
# Processing Record 26 of Set 8 | shitanjing
# Processing Record 27 of Set 8 | bani walid
# Processing Record 28 of Set 8 | bandar
# Processing Record 29 of Set 8 | tuy hoa
# Processing Record 30 of Set 8 | dunnville
# Processing Record 31 of Set 8 | antibes
# Processing Record 32 of Set 8 | vestbygda
# 'coord'
# Processing Record 33 of Set 8 | nasirabad
# Processing Record 34 of Set 8 | geraldton
# Processing Record 35 of Set 8 | vao
# Processing Record 36 of Set 8 | mangrol
# Processing Record 37 of Set 8 | walvis bay
# Processing Record 38 of Set 8 | mehamn
# Processing Record 39 of Set 8 | norman wells
# Processing Record 40 of Set 8 | novosheshminsk
# Processing Record 41 of Set 8 | luorong
# Processing Record 42 of Set 8 | olafsvik
# Processing Record 43 of Set 8 | virginia beach
# Processing Record 44 of Set 8 | bururi
# Processing Record 45 of Set 8 | kambove
# Processing Record 46 of Set 8 | porto novo
# Processing Record 47 of Set 8 | bulgan
# Processing Record 48 of Set 8 | taybad
# Processing Record 49 of Set 8 | las vegas
# Processing Record 50 of Set 8 | usinsk
# Processing Record 1 of Set 9 | luderitz
# Processing Record 2 of Set 9 | adrar
# Processing Record 3 of Set 9 | ketchikan
# Processing Record 4 of Set 9 | griffith
# Processing Record 5 of Set 9 | sawtell
# Processing Record 6 of Set 9 | grand baie
# Processing Record 7 of Set 9 | ostrovnoy
# Processing Record 8 of Set 9 | hofn
# Processing Record 9 of Set 9 | rapid valley
# Processing Record 10 of Set 9 | bacolod
# Processing Record 11 of Set 9 | oktyabrskoye
# Processing Record 12 of Set 9 | ratnagiri
# Processing Record 13 of Set 9 | whitehorse
# Processing Record 14 of Set 9 | tumannyy
# 'coord'
# Processing Record 15 of Set 9 | tanout
# Processing Record 16 of Set 9 | havoysund
# Processing Record 17 of Set 9 | mogadishu
# Processing Record 18 of Set 9 | namibe
# Processing Record 19 of Set 9 | sestri levante
# Processing Record 20 of Set 9 | karamay
# 'coord'
# Processing Record 21 of Set 9 | tsihombe
# 'coord'
# Processing Record 22 of Set 9 | antigonish
# Processing Record 23 of Set 9 | morgan city
# Processing Record 24 of Set 9 | kokemaki
# Processing Record 25 of Set 9 | bayan
# Processing Record 26 of Set 9 | byron bay
# Processing Record 27 of Set 9 | revelstoke
# Processing Record 28 of Set 9 | zapolyarnyy
# Processing Record 29 of Set 9 | villa de reyes
# Processing Record 30 of Set 9 | coahuayana
# Processing Record 31 of Set 9 | alamor
# Processing Record 32 of Set 9 | afonso bezerra
# Processing Record 33 of Set 9 | port-gentil
# Processing Record 34 of Set 9 | ucluelet
# Processing Record 35 of Set 9 | daru
# Processing Record 36 of Set 9 | gebre guracha
# Processing Record 37 of Set 9 | poso
# Processing Record 38 of Set 9 | maracaibo
# Processing Record 39 of Set 9 | kuche
# 'coord'
# Processing Record 40 of Set 9 | adolfo lopez mateos
# Processing Record 41 of Set 9 | trairi
# Processing Record 42 of Set 9 | roald
# Processing Record 43 of Set 9 | pochutla
# Processing Record 44 of Set 9 | fort-shevchenko
# Processing Record 45 of Set 9 | bathsheba
# Processing Record 46 of Set 9 | kavaratti
# Processing Record 47 of Set 9 | mfou
# Processing Record 48 of Set 9 | nakusp
# Processing Record 49 of Set 9 | tiruvottiyur
# 'coord'
# Processing Record 50 of Set 9 | safaga
# Processing Record 1 of Set 10 | sibu
# Processing Record 2 of Set 10 | bilma
# Processing Record 3 of Set 10 | bairiki
# Processing Record 4 of Set 10 | constantine
# Processing Record 5 of Set 10 | daur
# Processing Record 6 of Set 10 | suileng
# Processing Record 7 of Set 10 | kismayo
# Processing Record 8 of Set 10 | pesochnoye
# Processing Record 9 of Set 10 | pakxan
# Processing Record 10 of Set 10 | bayburt
# Processing Record 11 of Set 10 | anadyr
# Processing Record 12 of Set 10 | magistralnyy
# Processing Record 13 of Set 10 | codrington
# Processing Record 14 of Set 10 | am timan
# Processing Record 15 of Set 10 | taltal
# Processing Record 16 of Set 10 | fatezh
# Processing Record 17 of Set 10 | nagaur
# Processing Record 18 of Set 10 | vestmanna
# Processing Record 19 of Set 10 | corsicana
# Processing Record 20 of Set 10 | tautira
# Processing Record 21 of Set 10 | foam lake
# Processing Record 22 of Set 10 | arona
# Processing Record 23 of Set 10 | dedougou
# Processing Record 24 of Set 10 | santa maria del oro
# Processing Record 25 of Set 10 | xichang
# Processing Record 26 of Set 10 | necochea
# Processing Record 27 of Set 10 | kiunga
# Processing Record 28 of Set 10 | camocim
# Processing Record 29 of Set 10 | novomykolayivka
# Processing Record 30 of Set 10 | baker city
# Processing Record 31 of Set 10 | hasaki
# Processing Record 32 of Set 10 | zolotonosha
# Processing Record 33 of Set 10 | san lorenzo
# Processing Record 34 of Set 10 | ponazyrevo
# Processing Record 35 of Set 10 | iranshahr
# Processing Record 36 of Set 10 | aklavik
# Processing Record 37 of Set 10 | praia
# Processing Record 38 of Set 10 | bur gabo
# 'coord'
# Processing Record 39 of Set 10 | san borja
# Processing Record 40 of Set 10 | eureka
# Processing Record 41 of Set 10 | grand gaube
# Processing Record 42 of Set 10 | manzhouli
# Processing Record 43 of Set 10 | belyy yar
# Processing Record 44 of Set 10 | nakambala
# Processing Record 45 of Set 10 | alannay
# Processing Record 46 of Set 10 | jangipur
# Processing Record 47 of Set 10 | shenzhen
# Processing Record 48 of Set 10 | maragogi
# Processing Record 49 of Set 10 | stornoway
# Processing Record 50 of Set 10 | nguiu
# 'coord'
# Processing Record 1 of Set 11 | snasa
# Processing Record 2 of Set 11 | okhotsk
# Processing Record 3 of Set 11 | saint-denis
# Processing Record 4 of Set 11 | horizontina
# Processing Record 5 of Set 11 | laem sing
# Processing Record 6 of Set 11 | dezhou
# Processing Record 7 of Set 11 | khandyga
# Processing Record 8 of Set 11 | sao felix do xingu
# Processing Record 9 of Set 11 | mangai
# Processing Record 10 of Set 11 | sloboda
# Processing Record 11 of Set 11 | grindavik
# Processing Record 12 of Set 11 | paradwip
# 'coord'
# Processing Record 13 of Set 11 | yulara
# Processing Record 14 of Set 11 | san cristobal
# Processing Record 15 of Set 11 | borkenes
# Processing Record 16 of Set 11 | richards bay
# Processing Record 17 of Set 11 | henties bay
# Processing Record 18 of Set 11 | lahan
# Processing Record 19 of Set 11 | uribia
# Processing Record 20 of Set 11 | port lincoln
# Processing Record 21 of Set 11 | naze
# Processing Record 22 of Set 11 | vila
# Processing Record 23 of Set 11 | campbell river
# Processing Record 24 of Set 11 | kysyl-syr
# Processing Record 25 of Set 11 | nyimba
# Processing Record 26 of Set 11 | tuggurt
# 'coord'
# Processing Record 27 of Set 11 | olinda
# Processing Record 28 of Set 11 | ugra
# Processing Record 29 of Set 11 | shingu
# Processing Record 30 of Set 11 | riyadh
# Processing Record 31 of Set 11 | sandpoint
# Processing Record 32 of Set 11 | tambilil
# Processing Record 33 of Set 11 | chute-aux-outardes
# Processing Record 34 of Set 11 | quatre cocos
# Processing Record 35 of Set 11 | cap malheureux
# Processing Record 36 of Set 11 | westport
# Processing Record 37 of Set 11 | marsa matruh
# Processing Record 38 of Set 11 | talawdi
# 'coord'
# Processing Record 39 of Set 11 | roma
# Processing Record 40 of Set 11 | vila franca do campo
# Processing Record 41 of Set 11 | keningau
# Processing Record 42 of Set 11 | tabatinga
# Processing Record 43 of Set 11 | barra
# Processing Record 44 of Set 11 | kozachi laheri
# Processing Record 45 of Set 11 | yuzhno-yeniseyskiy
# 'coord'
# Processing Record 46 of Set 11 | camacha
# Processing Record 47 of Set 11 | mayo
# Processing Record 48 of Set 11 | mareeba
# Processing Record 49 of Set 11 | lagoa
# Processing Record 50 of Set 11 | smoky lake
# Processing Record 1 of Set 12 | mount isa
# Processing Record 2 of Set 12 | mirador
# Processing Record 3 of Set 12 | kutum
# Processing Record 4 of Set 12 | tefe
# Processing Record 5 of Set 12 | kaiyuan
# Processing Record 6 of Set 12 | kalach-na-donu
# Processing Record 7 of Set 12 | santa cruz de tenerife
# Processing Record 8 of Set 12 | aller
# Processing Record 9 of Set 12 | marsabit
# Processing Record 10 of Set 12 | nola
# Processing Record 11 of Set 12 | lanzhou
# Processing Record 12 of Set 12 | damghan
# Processing Record 13 of Set 12 | calbuco
# Processing Record 14 of Set 12 | bandarbeyla
# Processing Record 15 of Set 12 | sibolga
# Processing Record 16 of Set 12 | punta alta
# Processing Record 17 of Set 12 | pinega
# Processing Record 18 of Set 12 | union
# Processing Record 19 of Set 12 | nandu
# Processing Record 20 of Set 12 | bardiyah
# Processing Record 21 of Set 12 | zhigalovo
# Processing Record 22 of Set 12 | praia da vitoria
# Processing Record 23 of Set 12 | charcas
# Processing Record 24 of Set 12 | lata
# Processing Record 25 of Set 12 | kano
# Processing Record 26 of Set 12 | lolua
# 'coord'
# Processing Record 27 of Set 12 | asyut
# Processing Record 28 of Set 12 | manono
# Processing Record 29 of Set 12 | suntar
# Processing Record 30 of Set 12 | almaty
# Processing Record 31 of Set 12 | chinhoyi
# Processing Record 32 of Set 12 | constitucion
# Processing Record 33 of Set 12 | talnakh
# Processing Record 34 of Set 12 | saint anthony
# Processing Record 35 of Set 12 | ciras
# 'coord'
# Processing Record 36 of Set 12 | dibulla
# Processing Record 37 of Set 12 | port said
# Processing Record 38 of Set 12 | katangli
# Processing Record 39 of Set 12 | shelburne
# Processing Record 40 of Set 12 | phuket
# Processing Record 41 of Set 12 | tiarei
# Processing Record 42 of Set 12 | amahai
# Processing Record 43 of Set 12 | beyneu
# Processing Record 44 of Set 12 | bagdarin
# Processing Record 45 of Set 12 | jishou
# Processing Record 46 of Set 12 | dhidhdhoo
# Processing Record 47 of Set 12 | chara
# Processing Record 48 of Set 12 | tecoanapa
# Processing Record 49 of Set 12 | mtimbira
# Processing Record 50 of Set 12 | bealanana
# Processing Record 1 of Set 13 | pampa
# Processing Record 2 of Set 13 | hammerfest
# Processing Record 3 of Set 13 | kuala terengganu
# Processing Record 4 of Set 13 | tual
# Processing Record 5 of Set 13 | kholmy
# Processing Record 6 of Set 13 | palabuhanratu
# 'coord'
# Processing Record 7 of Set 13 | birao
# Processing Record 8 of Set 13 | plettenberg bay
# Processing Record 9 of Set 13 | berbera
# Processing Record 10 of Set 13 | road town
# Processing Record 11 of Set 13 | wanaka
# Processing Record 12 of Set 13 | black river
# Processing Record 13 of Set 13 | wamba
# Processing Record 14 of Set 13 | sisimiut
# Processing Record 15 of Set 13 | bonavista
# Processing Record 16 of Set 13 | drumnadrochit
# Processing Record 17 of Set 13 | okha
# Processing Record 18 of Set 13 | san quintin
# Processing Record 19 of Set 13 | kalmunai
# Processing Record 20 of Set 13 | airai
# Processing Record 21 of Set 13 | fenoarivo
# Processing Record 22 of Set 13 | acarau
# Processing Record 23 of Set 13 | nanakuli
# Processing Record 24 of Set 13 | lindi
# Processing Record 25 of Set 13 | ancud
# Processing Record 26 of Set 13 | monrovia
# Processing Record 27 of Set 13 | puerto quijarro
# Processing Record 28 of Set 13 | dezful
# Processing Record 29 of Set 13 | san antonio
# Processing Record 30 of Set 13 | mingaora
# Processing Record 31 of Set 13 | sokoto
# Processing Record 32 of Set 13 | brae
# Processing Record 33 of Set 13 | paso de los toros
# Processing Record 34 of Set 13 | taksimo
# Processing Record 35 of Set 13 | kota kinabalu
# Processing Record 36 of Set 13 | artyk
# 'coord'
# Processing Record 37 of Set 13 | teya
# Processing Record 38 of Set 13 | karakendzha
# 'coord'
# Processing Record 39 of Set 13 | sapa
# Processing Record 40 of Set 13 | kargasok
# Processing Record 41 of Set 13 | dharchula
# Processing Record 42 of Set 13 | novo aripuana
# Processing Record 43 of Set 13 | vaitupu
# 'coord'
# Processing Record 44 of Set 13 | oussouye
# Processing Record 45 of Set 13 | filadelfia
# Processing Record 46 of Set 13 | awjilah
# Processing Record 47 of Set 13 | togur
# Processing Record 48 of Set 13 | zverinogolovskoye
# Processing Record 49 of Set 13 | makakilo city
# Processing Record 50 of Set 13 | zharkent
# Processing Record 1 of Set 14 | olga
# Processing Record 2 of Set 14 | wichita falls
# Processing Record 3 of Set 14 | skegness
# Processing Record 4 of Set 14 | santa maria
# Processing Record 5 of Set 14 | turayf
# Processing Record 6 of Set 14 | morondava
# Processing Record 7 of Set 14 | fort smith
# Processing Record 8 of Set 14 | santa eulalia del rio
# 'coord'
# Processing Record 9 of Set 14 | karkaralinsk
# 'coord'
# Processing Record 10 of Set 14 | talara
# Processing Record 11 of Set 14 | maningrida
# Processing Record 12 of Set 14 | umm lajj
# Processing Record 13 of Set 14 | losinyy
# Processing Record 14 of Set 14 | ulety
# Processing Record 15 of Set 14 | botshabelo
# Processing Record 16 of Set 14 | cochrane
# Processing Record 17 of Set 14 | kloulklubed
# Processing Record 18 of Set 14 | ayan
# Processing Record 19 of Set 14 | ngukurr
# 'coord'
# Processing Record 20 of Set 14 | angoche
# Processing Record 21 of Set 14 | armidale
# Processing Record 22 of Set 14 | oktyabrskiy
# Processing Record 23 of Set 14 | pangnirtung
# Processing Record 24 of Set 14 | boa vista
# Processing Record 25 of Set 14 | bundaberg
# Processing Record 26 of Set 14 | dwarka
# Processing Record 27 of Set 14 | ondjiva
# Processing Record 28 of Set 14 | vertientes
# Processing Record 29 of Set 14 | gongzhuling
# Processing Record 30 of Set 14 | alyangula
# Processing Record 31 of Set 14 | margina
# Processing Record 32 of Set 14 | kijang
# Processing Record 33 of Set 14 | kamaishi
# Processing Record 34 of Set 14 | gwanda
# Processing Record 35 of Set 14 | samarai
# Processing Record 36 of Set 14 | novita
# Processing Record 37 of Set 14 | redmond
# Processing Record 38 of Set 14 | bolungarvik
# 'coord'
# Processing Record 39 of Set 14 | hato mayor
# Processing Record 40 of Set 14 | izsak
# Processing Record 41 of Set 14 | krasnyy chikoy
# Processing Record 42 of Set 14 | hobyo
# Processing Record 43 of Set 14 | rawannawi
# 'coord'
# Processing Record 44 of Set 14 | lusaka
# Processing Record 45 of Set 14 | pontes e lacerda
# Processing Record 46 of Set 14 | ostersund
# Processing Record 47 of Set 14 | cacoal
# Processing Record 48 of Set 14 | kieta
# Processing Record 49 of Set 14 | humaita
# Processing Record 50 of Set 14 | zhuhai
# Processing Record 1 of Set 15 | north vernon
# Processing Record 2 of Set 15 | papasquiaro
# 'coord'
# Processing Record 3 of Set 15 | zhovtneve
# Processing Record 4 of Set 15 | chitrakonda
# Processing Record 5 of Set 15 | scotts valley
# Processing Record 6 of Set 15 | ivot
# Processing Record 7 of Set 15 | kuusamo
# Processing Record 8 of Set 15 | auki
# Processing Record 9 of Set 15 | marsh harbour
# Processing Record 10 of Set 15 | coihaique
# Processing Record 11 of Set 15 | terrak
# Processing Record 12 of Set 15 | korla
# Processing Record 13 of Set 15 | deda
# Processing Record 14 of Set 15 | ballina
# Processing Record 15 of Set 15 | moussoro
# Processing Record 16 of Set 15 | mikun
# Processing Record 17 of Set 15 | castrillon
# Processing Record 18 of Set 15 | goderich
# Processing Record 19 of Set 15 | at-bashi
# Processing Record 20 of Set 15 | nagapattinam
# Processing Record 21 of Set 15 | aksha
# Processing Record 22 of Set 15 | litoral del san juan
# 'coord'
# Processing Record 23 of Set 15 | wentzville
# Processing Record 24 of Set 15 | figeac
# Processing Record 25 of Set 15 | lypnyazhka
# Processing Record 26 of Set 15 | marienburg
# Processing Record 27 of Set 15 | kikwit
# Processing Record 28 of Set 15 | boende
# Processing Record 29 of Set 15 | bressanone
# Processing Record 30 of Set 15 | flin flon
# Processing Record 31 of Set 15 | myitkyina
# Processing Record 32 of Set 15 | naryan-mar
# Processing Record 33 of Set 15 | faya
# Processing Record 34 of Set 15 | pacific grove
# Processing Record 35 of Set 15 | kindersley
# Processing Record 36 of Set 15 | fonte boa
# Processing Record 37 of Set 15 | beringovskiy
# Processing Record 38 of Set 15 | nizhniy odes
# Processing Record 39 of Set 15 | liverpool
# Processing Record 40 of Set 15 | save
# Processing Record 41 of Set 15 | kampot
# Processing Record 42 of Set 15 | soyo
# Processing Record 43 of Set 15 | zhangjiakou
# Processing Record 44 of Set 15 | fairbanks
# Processing Record 45 of Set 15 | machali
# Processing Record 46 of Set 15 | gaffney
# Processing Record 47 of Set 15 | paraibano
# Processing Record 48 of Set 15 | gat
# Processing Record 49 of Set 15 | innisfail
# Processing Record 50 of Set 15 | upata
# Processing Record 1 of Set 16 | rusape
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     52.48        96         100
# 1    Butaritari      KI   3.0707  172.7902     80.02        80          54
# 2    Georgetown      MY   5.4112  100.3354     82.33        88          20
# 3     Churapcha      RU  62.0025  132.4325    -23.58       100         100
# 4  Longyearbyen      SJ  78.2186   15.6401     17.44        67           0
# 5     Jamestown      US  42.0970  -79.2353     31.08        55         100
# 6  Komsomolskiy      UZ  40.4272   71.7189     35.02        86           4
# 7       Ushuaia      AR -54.8000  -68.3000     47.82        61          75
# 8       Isangel      VU -19.5500  169.2667     79.11        87         100
# 9      Hermanus      ZA -34.4187   19.2345     65.89        76          49
#
#    Wind Speed Current Description
# 0        1.88          light rain
# 1       11.41       moderate rain
# 2        2.30          few clouds
# 3        2.35     overcast clouds
# 4        3.44           clear sky
# 5       12.66          light snow
# 6        6.91                mist
# 7       14.97       broken clouds
# 8        6.29     overcast clouds
# 9       10.16    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
